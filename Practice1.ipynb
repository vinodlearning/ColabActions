# %%
## My practice sessions

# %%
import pandas as pd

# %%
import numpy as np

# %%
np.random.seed(42)

# %%
data={

      "feature1": np.random.rand(100)*100,
      "feature2": np.random.randint(0,100,100),
      "category_feature": np.random.choice(["VINOD","GUMMADI","KUMAR"],100),
      "target": np.random.randint(0,3,100)
}

# %%
data
# Out:
# {'feature1': array([37.45401188, 95.07143064, 73.19939418, 59.86584842, 15.60186404,
#         15.59945203,  5.80836122, 86.61761458, 60.11150117, 70.80725778,
#          2.05844943, 96.99098522, 83.24426408, 21.23391107, 18.18249672,
#         18.34045099, 30.4242243 , 52.47564316, 43.19450186, 29.12291402,
#         61.18528947, 13.94938607, 29.21446485, 36.63618433, 45.60699842,
#         78.51759614, 19.96737822, 51.42344384, 59.24145689,  4.64504127,
#         60.75448519, 17.05241237,  6.5051593 , 94.88855373, 96.56320331,
#         80.83973481, 30.46137692,  9.7672114 , 68.42330265, 44.01524937,
#         12.20382348, 49.51769101,  3.43885211, 90.93204021, 25.87799816,
#         66.25222844, 31.17110761, 52.00680212, 54.67102793, 18.48544555,
#         96.95846278, 77.51328234, 93.94989416, 89.48273504, 59.78999788,
#         92.1874235 ,  8.84925021, 19.59828624,  4.52272889, 32.53303308,
#         38.86772897, 27.13490318, 82.87375092, 35.67533267, 28.09345097,
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      feature1  feature2 category_feature  target
# 0   37.454012        62            KUMAR       0
# 1   95.071431        95            KUMAR       0
# 2   73.199394        51            KUMAR       1
# 3   59.865848        95          GUMMADI       0
# 4   15.601864         3            KUMAR       2
# ..        ...       ...              ...     ...
# 95  49.379560        72            VINOD       1
# 96  52.273283        58          GUMMADI       2
# 97  42.754102        69            KUMAR       1
# 98   2.541913        79            VINOD       0
# 99  10.789143        92            VINOD       1
#
# [100 rows x 4 columns]

# %%
df.loc[0:5,"feature1"]=np.nan

# %%
df
# Out:
#      feature1  feature2 category_feature  target
# 0         NaN        62            KUMAR       0
# 1         NaN        95            KUMAR       0
# 2         NaN        51            KUMAR       1
# 3         NaN        95          GUMMADI       0
# 4         NaN         3            KUMAR       2
# ..        ...       ...              ...     ...
# 95  49.379560        72            VINOD       1
# 96  52.273283        58          GUMMADI       2
# 97  42.754102        69            KUMAR       1
# 98   2.541913        79            VINOD       0
# 99  10.789143        92            VINOD       1
#
# [100 rows x 4 columns]

# %%
df_duplicate=pd.concat([df,df.iloc[0:5]],ignore_index=True)

# %%
df_duplicate
# Out:
#      feature1  feature2 category_feature  target
# 0         NaN        62            KUMAR       0
# 1         NaN        95            KUMAR       0
# 2         NaN        51            KUMAR       1
# 3         NaN        95          GUMMADI       0
# 4         NaN         3            KUMAR       2
# ..        ...       ...              ...     ...
# 100       NaN        62            KUMAR       0
# 101       NaN        95            KUMAR       0
# 102       NaN        51            KUMAR       1
# 103       NaN        95          GUMMADI       0
# 104       NaN         3            KUMAR       2
#
# [105 rows x 4 columns]

# %%
df_duplicate.head(10)
# Out:
#     feature1  feature2 category_feature  target
# 0        NaN        62            KUMAR       0
# 1        NaN        95            KUMAR       0
# 2        NaN        51            KUMAR       1
# 3        NaN        95          GUMMADI       0
# 4        NaN         3            KUMAR       2
# 5        NaN        93            KUMAR       2
# 6   5.808361        22            KUMAR       0
# 7  86.617615        14            KUMAR       2
# 8  60.111501        42            VINOD       0
# 9  70.807258        28            VINOD       0

# %%
df_duplicate.tail()
# Out:
#      feature1  feature2 category_feature  target
# 100       NaN        62            KUMAR       0
# 101       NaN        95            KUMAR       0
# 102       NaN        51            KUMAR       1
# 103       NaN        95          GUMMADI       0
# 104       NaN         3            KUMAR       2

# %%
df_duplicate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   feature1          94 non-null     float64
#  1   feature2          105 non-null    int64
#  2   category_feature  105 non-null    object
#  3   target            105 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.4+ KB

# %%
## Summary statistics
df_duplicate.describe(include="all")
# Out:
#          feature1    feature2 category_feature      target
# count   94.000000  105.000000              105  105.000000
# unique        NaN         NaN                3         NaN
# top           NaN         NaN            KUMAR         NaN
# freq          NaN         NaN               38         NaN
# mean    46.861866   51.771429              NaN    1.028571
# std     29.763842   29.924989              NaN    0.790048
# min      0.552212    0.000000              NaN    0.000000
# 25%     19.666607   27.000000              NaN    0.000000
# 50%     46.414245   55.000000              NaN    1.000000
# 75%     72.945643   74.000000              NaN    2.000000
# max     98.688694   97.000000              NaN    2.000000

# %%
##Missing values
df_duplicate.isnull().sum()
# Out:
# feature1            11
# feature2             0
# category_feature     0
# target               0
# dtype: int64

# %%
#duplciated in rows -->count

df_duplicate.duplicated().sum()
# Out:
# 5

# %%
#duplicate values remove into data set
df_duplicate_df=df_duplicate.drop_duplicates()

# %%
df_duplicate_df
# Out:
#      feature1  feature2 category_feature  target
# 0         NaN        62            KUMAR       0
# 1         NaN        95            KUMAR       0
# 2         NaN        51            KUMAR       1
# 3         NaN        95          GUMMADI       0
# 4         NaN         3            KUMAR       2
# ..        ...       ...              ...     ...
# 95  49.379560        72            VINOD       1
# 96  52.273283        58          GUMMADI       2
# 97  42.754102        69            KUMAR       1
# 98   2.541913        79            VINOD       0
# 99  10.789143        92            VINOD       1
#
# [100 rows x 4 columns]

# %%
## Handling missing values

df_duplicate_df
# Out:
#      feature1  feature2 category_feature  target
# 0         NaN        62            KUMAR       0
# 1         NaN        95            KUMAR       0
# 2         NaN        51            KUMAR       1
# 3         NaN        95          GUMMADI       0
# 4         NaN         3            KUMAR       2
# ..        ...       ...              ...     ...
# 95  49.379560        72            VINOD       1
# 96  52.273283        58          GUMMADI       2
# 97  42.754102        69            KUMAR       1
# 98   2.541913        79            VINOD       0
# 99  10.789143        92            VINOD       1
#
# [100 rows x 4 columns]

# %%
df_fill=df_duplicate_df.copy()

# %%
df_fill
# Out:
#      feature1  feature2 category_feature  target
# 0         NaN        62            KUMAR       0
# 1         NaN        95            KUMAR       0
# 2         NaN        51            KUMAR       1
# 3         NaN        95          GUMMADI       0
# 4         NaN         3            KUMAR       2
# ..        ...       ...              ...     ...
# 95  49.379560        72            VINOD       1
# 96  52.273283        58          GUMMADI       2
# 97  42.754102        69            KUMAR       1
# 98   2.541913        79            VINOD       0
# 99  10.789143        92            VINOD       1
#
# [100 rows x 4 columns]
