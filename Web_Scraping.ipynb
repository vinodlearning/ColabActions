# %% [markdown]
# <a href="https://colab.research.google.com/github/vinodlearning/ColabActions/blob/main/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## This is my second practice session for web scraping

# %%
import pandas
import json
import requests
from bs4 import BeautifulSoup

# %%
pip install beautifulsoup4

# %%
url ="https://www.sc.fsu.edu/people/administration"

# %%
##sending request

response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.raise_for_status()

# %%
##parse html content
domobjct=BeautifulSoup(response.text, 'html.parser')

# %%
domobjct
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- BEGIN JOOMLA HEAD -->
# <meta charset="utf-8"/>
# <meta content="Copyright © Florida State University - All Rights Reserved" name="rights"/>
# <meta content="Michael McDonald" name="author"/>
# <meta content="Burgess, Bill	Publications/Graphics Artist	406 DSL	(850) 644.4275
#
#
# Farmer, Cecelia	Graduate Program Assistant / Executive Secretary to the Director	400A DSL	(850) 644.0143
#
#
# Johnson, Anne	Senior Program Assistant	403 DSL	(850) 644.7054
#
#
# Keyser, Paul	Program Assistant	404 DSL	(850) 644.1864
#
#
# LaCombe, Lynn	Office Assistant	409A DSL	(850) 645.0304
#
#
# Locke, Michele	Coordinator, Administrative Services	405 DSL	(850) 644.2273" name="description"/>
# <meta content="Joomla! - Open Source Content Management" name="generator"/>
# <title>Administration - FSUSciComp</title>
# <link href="https://www.sc.fsu.edu/search?format=opensearch" rel="search" title="OpenSearch FSUSciComp" type="application/opensearchdescription+xml"/>
# ...

# %%
## we have to extract the data from dom object so creating / declaring one data set
data=[]

# %%
## serach the table data in dom object and extract it
tableData=domobjct.find("table")

# %%
## we got entire <table> tag data from dom obejct
## need to extract the exact data from table object

if tableData:
  rows=tableData.findAll("tr");
  for row in rows:
    cols=row.findAll("td");
    cols=[col.text.strip() for col in cols]
    data.append(cols)

# %%
data
# Out:
# [['',
#   'Davis,\xa0Liston\nAdministrative Associate\n\xa0This email address is being protected from spambots. You need JavaScript enabled to view it.\n\xa0409\xa0DSL\n\xa0(850)\xa0645-0304'],
#  ['',
#   'Farmer,\xa0Cecelia\nAdmin Support Assistant\n\xa0This email address is being protected from spambots. You need JavaScript enabled to view it.\n\xa0402B\xa0DSL'],
#  ['',
#   "Fowler,\xa0Karey\nAcademic Advisor\n\n Karey's LinkedIn Profile\xa0This email address is being protected from spambots. You need JavaScript enabled to view it.\n\xa0406\xa0DSL\n\xa0(850)\xa0644-0143"],
#  ['',
#   'Keyser,\xa0Paul\nAdministrative Assistant / Facilities, Property, & Immigration\n\xa0This email address is being protected from spambots. You need JavaScript enabled to view it.\n\xa0404\xa0DSL\n\xa0(850)\xa0644-1864']]

# %%
cleaned_data = [[item.replace("This email address is being protected from spambots. You need JavaScript enabled to view it.", "") for item in sublist] for sublist in data]
cleaned_data = [[item.replace("\n", "") for item in sublist] for sublist in cleaned_data]

cleaned_data
# Out:
# [['',
#   'Davis,\xa0ListonAdministrative Associate\xa0\xa0409\xa0DSL\xa0(850)\xa0645-0304'],
#  ['', 'Farmer,\xa0CeceliaAdmin Support Assistant\xa0\xa0402B\xa0DSL'],
#  ['',
#   "Fowler,\xa0KareyAcademic Advisor Karey's LinkedIn Profile\xa0\xa0406\xa0DSL\xa0(850)\xa0644-0143"],
#  ['',
#   'Keyser,\xa0PaulAdministrative Assistant / Facilities, Property, & Immigration\xa0\xa0404\xa0DSL\xa0(850)\xa0644-1864']]

# %%
import pandas as pd

# %%
##df=pd.DataFrame(cleaned_data[1:],columns=cleaned_data[0])
df=pd.DataFrame(cleaned_data)

# %%
df
# Out:
#   0                                                  1
# 0    Davis, ListonAdministrative Associate  409 DSL...
# 1     Farmer, CeceliaAdmin Support Assistant  402B DSL
# 2    Fowler, KareyAcademic Advisor Karey's LinkedIn...
# 3    Keyser, PaulAdministrative Assistant / Facilit...
